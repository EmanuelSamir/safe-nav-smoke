# %%
import pandas as pd
import numpy as np

# %%
ls
# Out:
# cvar.png                  mppi_only.png             static_map_warm_hj_0.gif
# high_prec.png             proposal.png              static_map_warm_hj_1.gif
# high_resolution_test.png  proposal_2.png            static_map_warm_hj_2.gif
# hj_alone_no_warmup.png    results.ipynb             static_map_warm_hj_3.gif
# last_version.png          results_proposal.csv      static_map_warm_hj_4.gif
# mppi_fixed.png            static_map_warm_hj.gif

# %%
df = pd.read_csv("results_proposal.csv")

# %%
np.unique(df["time in fail"] > 0.01, return_counts=True)
# Out:
# (array([False,  True]), array([ 8, 16]))

# %%
df
# Out:
#     total_time  time in fail  time in non-fail  terminated  \
# 0          9.6           0.2               9.4        True
# 1         11.6           1.1              10.5        True
# 2         12.0           0.6              11.4        True
# 3         14.3           1.7              12.6        True
# 4         11.1           0.4              10.7        True
# 5         12.9           0.0              12.9        True
# 6         10.1           0.0              10.1        True
# 7         11.2           0.7              10.5        True
# 8          9.9           1.1               8.8        True
# 9         12.1           0.1              12.0        True
# 10         8.5           0.0               8.5        True
# 11        10.6           0.5              10.1        True
# 12        11.3           0.4              10.9        True
# 13        10.3           0.0              10.3        True
# 14        13.6           2.1              11.5        True
# ...

# %%
t_fail_mu = df["time in fail"].mean()
t_nonfail_mu = df["time in non-fail"].mean()

t_fail_std = df["time in fail"].std()
t_nonfail_std = df["time in non-fail"].std()

t_total = df["total_time"].mean()
t_total_std = df["total_time"].std()


print(t_fail_mu)
print(t_fail_std)

print(t_nonfail_mu)
print(t_nonfail_std)

print(t_total)
print(t_total_std)
# Out:
# 0.6125
# 0.7029827754708473
# 10.558333333333334
# 1.2638507983855176
# 11.170833333333333
# 1.607720278143441
